# %%
import pandas as pd
import numpy as np
from datetime import date

# %%
abc=pd.read_csv('HR.csv')

# %%
abc
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
 abc.size
# Out:
# 11196

# %%
abc.shape
# Out:
# (311, 36)

# %%
abc.info
# Out:
# <bound method DataFrame.info of                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
abc.head(11)
# Out:
#                Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0        Adinolfi, Wilson  K  10026          0                0         1
# 1   Ait Sidi, Karthikeyan     10084          1                1         1
# 2          Akinkuolie, Sarah  10196          1                1         0
# 3               Alagbe,Trina  10088          1                1         0
# 4           Anderson, Carol   10069          0                2         0
# 5          Anderson, Linda    10002          0                0         0
# 6            Andreola, Colby  10194          0                0         0
# 7                Athwal, Sam  10062          0                4         1
# 8           Bachiochi, Linda  10114          0                0         0
# 9         Bacong, Alejandro   10250          0                2         1
# 10      Baczenski, Rachael    10252          1                1         0
#
#     EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# ...

# %%
abc.tail(11)
# Out:
#              Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 300        Whittier, Scott  10072          0                0         1
# 301          Wilber, Barry  10048          1                1         1
# 302          Wilkes, Annie  10204          0                2         0
# 303  Williams, Jacquelyn    10264          0                0         0
# 304     Winthrop, Jordan    10033          0                0         1
# 305          Wolk, Hang  T  10174          0                0         0
# 306         Woodson, Jason  10135          0                0         1
# 307     Ybarra, Catherine   10301          0                0         0
# 308       Zamora, Jennifer  10010          0                0         0
# 309            Zhou, Julia  10043          0                0         0
# 310          Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# ...

# %%
abc.isnull()
# Out:
#      Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 0            False  False      False            False     False        False
# 1            False  False      False            False     False        False
# 2            False  False      False            False     False        False
# 3            False  False      False            False     False        False
# 4            False  False      False            False     False        False
# ..             ...    ...        ...              ...       ...          ...
# 306          False  False      False            False     False        False
# 307          False  False      False            False     False        False
# 308          False  False      False            False     False        False
# 309          False  False      False            False     False        False
# 310          False  False      False            False     False        False
#
# ...

# %%
abc.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
abc.isnull().sum().sum()
# Out:
# 215

# %%
data=abc.loc[:, ['DeptID','ManagerID','ManagerName']]

# %%
data
# Out:
#      DeptID  ManagerID     ManagerName
# 0         5       22.0  Michael Albert
# 1         3        4.0      Simon Roup
# 2         5       20.0  Kissy Sullivan
# 3         5       16.0    Elijiah Gray
# 4         5       39.0  Webster Butler
# ..      ...        ...             ...
# 306       5       20.0  Kissy Sullivan
# 307       5       12.0  Brannon Miller
# 308       3        2.0      Janet King
# 309       3        4.0      Simon Roup
# 310       5       14.0   David Stanley
#
# [311 rows x 3 columns]

# %%
abc['DateofTermination']=abc['DateofTermination'].replace(to_replace=np.nan,value=0)

# %%
abc
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
abc.isnull().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     8
# RecruitmentSource             0
# ...

# %%
abc['ManagerID']=data['ManagerID'].replace(to_replace=np.nan,value=39.0)

# %%
abc.isnull().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# ...

# %%
count_emp=abc.groupby('Department')['Department'].count()

# %%
count_emp
# Out:
# Department
# Admin Offices             9
# Executive Office          1
# IT/IS                    50
# Production              209
# Sales                    31
# Software Engineering     11
# Name: Department, dtype: int64

# %%
Avg_Salary=abc.groupby('Department')['Salary'].mean()

# %%
Avg_Salary
# Out:
# Department
# Admin Offices            71791.888889
# Executive Office        250000.000000
# IT/IS                    97064.640000
# Production               59953.545455
# Sales                    69061.258065
# Software Engineering     94989.454545
# Name: Salary, dtype: float64

# %%
sex_Salary=abc.groupby(['Department','Sex'],as_index=False).Salary.mean()

# %%
sex_Salary
# Out:
#               Department Sex         Salary
# 0          Admin Offices   F   70926.333333
# 1          Admin Offices  M    73523.000000
# 2       Executive Office   F  250000.000000
# 3                  IT/IS   F   94593.000000
# 4                  IT/IS  M    99006.642857
# 5      Production          F   59620.420635
# 6      Production         M    60459.253012
# 7                  Sales   F   72016.666667
# 8                  Sales  M    66290.562500
# 9   Software Engineering   F   96906.166667
# 10  Software Engineering  M    92689.400000

# %%
Recruitmentsource=abc.groupby(['Department','RecruitmentSource']).size().reset_index(name='counts')

# %%
Recruitmentsource
# Out:
#               Department        RecruitmentSource  counts
# 0          Admin Offices            CareerBuilder       1
# 1          Admin Offices       Diversity Job Fair       3
# 2          Admin Offices                   Indeed       2
# 3          Admin Offices                    Other       1
# 4          Admin Offices                  Website       2
# 5       Executive Office                   Indeed       1
# 6                  IT/IS            CareerBuilder       2
# 7                  IT/IS       Diversity Job Fair       4
# 8                  IT/IS        Employee Referral      13
# 9                  IT/IS            Google Search       1
# 10                 IT/IS                   Indeed      19
# 11                 IT/IS                 LinkedIn      11
# 12     Production                   CareerBuilder      16
# 13     Production              Diversity Job Fair      17
# 14     Production               Employee Referral      16
# ...

# %%
Employee_Name=input('Enter name:')
# Out:
# Enter name:Akinkuolie

# %%
Start_year=int(input('Enter the start year:'))
Start_month=int(input('Enter the start month:'))
Start_day=int(input('Enter the start day:'))
Start_date=date(Start_year,Start_month,Start_day)
Start_date
# Out:
# Enter the start year:2011
# Enter the start month:9
# Enter the start day:5
# datetime.date(2011, 9, 5)

# %%
T_year=int(input('Enter the Terminated year:'))
T_month=int(input('Enter the Terminated month:'))
T_day=int(input('Enter the Terminated day:'))
T_date=date(T_year,T_month,T_day)
T_date
# Out:
# Enter the Terminated year:2012
# Enter the Terminated month:9
# Enter the Terminated day:24
# datetime.date(2012, 9, 24)

# %%
business_days=pd.bdate_range(Start_date,T_date)

# %%
business_days
# Out:
# DatetimeIndex(['2011-09-05', '2011-09-06', '2011-09-07', '2011-09-08',
#                '2011-09-09', '2011-09-12', '2011-09-13', '2011-09-14',
#                '2011-09-15', '2011-09-16',
#                ...
#                '2012-09-11', '2012-09-12', '2012-09-13', '2012-09-14',
#                '2012-09-17', '2012-09-18', '2012-09-19', '2012-09-20',
#                '2012-09-21', '2012-09-24'],
#               dtype='datetime64[ns]', length=276, freq='B')

# %%
print('Employee name:',Employee_Name,'working_days',len(business_days))
# Out:
# Employee name: Akinkuolie working_days 276
